# %%
arr = [
    {
        "name": "Sairil.Test",
        "description": "This is a test description for Sairil.Test",
        "version": "1.0.0",
    },
    {
        "name": "Sairil.Test2",
        "description": "This is a test description for Sairil.Test2",
        "version": "1.0.0",
    },
    {
        "name": "Sairil.Test3",
        "description": "This is a test description for Sairil.Test3",
        "version": "1.0.0",
    }
]

for a in arr:
    print(f"Name: {a['name']}, Description: {a['description']}, Version: {a['version']}")
# Out:
# Name: Sairil.Test, Description: This is a test description for Sairil.Test, Version: 1.0.0
# Name: Sairil.Test2, Description: This is a test description for Sairil.Test2, Version: 1.0.0
# Name: Sairil.Test3, Description: This is a test description for Sairil.Test3, Version: 1.0.0
